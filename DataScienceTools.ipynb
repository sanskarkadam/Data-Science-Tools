# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# ## Introduction
#
# This notebook provides an overview of data science languages, libraries, and tools.
# It also demonstrates simple arithmetic operations using Python.

# %% [markdown]
# ## Data Science Languages
#
# - Python
# - R
# - SQL
# - Julia
# - Scala

# %% [markdown]
# ## Data Science Libraries
#
# - NumPy
# - Pandas
# - Matplotlib
# - Seaborn
# - Scikit-learn
# - TensorFlow

# %% [markdown]
# ## Data Science Tools
#
# | Tool | Purpose |
# |-----|--------|
# | Jupyter Notebook | Interactive analysis |
# | RStudio | R development |
# | Apache Spark | Big data processing |
# | Tableau | Data visualization |
# | GitHub | Version control |

# %% [markdown]
# ## Arithmetic Expression Examples
#
# Below are examples of arithmetic expressions evaluated using Python.

# %%
(3 * 4) + 5
# Out:
# 17

# %%
minutes = 200
hours = minutes / 60
hours
# Out:
# 3.3333333333333335

# %% [markdown]
# ## Objectives
#
# - List data science languages
# - Identify data science libraries
# - Show data science tools
# - Perform arithmetic operations
# - Convert minutes to hours

# %% [markdown]
# ## Author
#
# Sanskar Kadam
